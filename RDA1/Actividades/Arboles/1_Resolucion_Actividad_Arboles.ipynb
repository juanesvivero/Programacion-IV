# %% [markdown]
# # ✅ Resolución de la Actividad: Árboles Binarios

# %% [markdown]
# ### Para que los siguientes códigos funcionen correctamente:
#
# import matplotlib.pyplot as plt
# import networkx as nx
#
# Necesitas instalar las siguientes bibliotecas con pip:
#
# - pip install matplotlib networkx
#
# Detalle:
#
# * matplotlib: para generar gráficos, en este caso, visualizar el grafo.
#
# * networkx: para crear y manipular grafos (dirigidos o no dirigidos).
#
# Si estás usando Jupyter Notebook o JupyterLab, también puedes asegurarte de visualizar correctamente con:
#
# - pip install notebook

# %% [markdown]
# ## 🧪 Tarea 1: Árbol binario de 7 nodos
#
# Valores insertados: **50, 30, 70, 20, 40, 60, 80**
#
# Representación del árbol binario:
#
# ```
#         50         ← raíz (nivel 0)
#        /  \
#      30    70      ← nivel 1
#     / \    / \
#   20  40  60  80   ← nivel 2
# ```
#
# ### Identificación de elementos:
#
# | Elemento       | Valor(es)                              |
# |----------------|----------------------------------------|
# | **Raíz**       | 50                                     |
# | **Hojas**      | 20, 40, 60, 80                         |
# | **Nodos internos** | 30, 70                              |
# | **Nivel 0**    | 50                                     |
# | **Nivel 1**    | 30, 70                                 |
# | **Nivel 2**    | 20, 40, 60, 80                         |
# | **Altura**     | 2                                      |

# %%
# Importamos la librería matplotlib para generar gráficos (plt es el alias común).
import matplotlib.pyplot as plt

# Importamos la librería networkx para trabajar con grafos dirigidos (nx es el alias común).
import networkx as nx

# Creamos un nuevo grafo dirigido (DiGraph significa "Directed Graph", es decir, con flechas).
G = nx.DiGraph()

# Definimos las conexiones (aristas) entre los nodos. Cada tupla representa una relación padre → hijo.
edges = [
    (50, 30),  # El nodo raíz 50 tiene como hijo izquierdo al 30
    (50, 70),  # El nodo raíz 50 tiene como hijo derecho al 70
    (30, 20),  # El nodo 30 tiene como hijo izquierdo al 20
    (30, 40),  # El nodo 30 tiene como hijo derecho al 40
    (70, 60),  # El nodo 70 tiene como hijo izquierdo al 60
    (70, 80)   # El nodo 70 tiene como hijo derecho al 80
]

# Agregamos todas las aristas al grafo G. NetworkX creará automáticamente los nodos implicados.
G.add_edges_from(edges)

# Definimos las posiciones en el plano (x, y) para que el árbol se visualice de forma jerárquica.
pos = {
    50: (0, 2),         # Raíz del árbol, nivel 0
    30: (-1.5, 1),      # Hijo izquierdo de 50, nivel 1
    70: (1.5, 1),       # Hijo derecho de 50, nivel 1
    20: (-2.2, 0),      # Hijo izquierdo de 30, nivel 2
    40: (-0.8, 0),      # Hijo derecho de 30, nivel 2
    60: (0.8, 0),       # Hijo izquierdo de 70, nivel 2
    80: (2.2, 0)        # Hijo derecho de 70, nivel 2
}

# Creamos una nueva figura con tamaño de 10x6 pulgadas
plt.figure(figsize=(10, 6))

# Dibujamos el grafo con las siguientes características:
# - G: el grafo que creamos
# - pos: las coordenadas (x, y) de cada nodo
# - with_labels=True: para mostrar los valores de cada nodo
# - node_color='lightgreen': color de los nodos
# - node_size=1800: tamaño de cada nodo
# - font_size=14: tamaño del texto
# - font_weight='bold': texto en negrita
# - arrows=False: no mostrar flechas (por ser árbol binario sin orientación visual)
nx.draw(
    G, pos,
    with_labels=True,
    node_color='lightgreen',
    node_size=1800,
    font_size=14,
    font_weight='bold',
    arrows=False
)

# Título del gráfico
plt.title("Árbol Binario de Búsqueda: [50, 30, 70, 20, 40, 60, 80]", fontsize=14)

# Oculta los ejes del gráfico
plt.axis('off')

# Muestra el gráfico en pantalla
plt.show()

# %% [markdown]
# ## 🧪 Tarea 2 (opcional): Árbol binario en expresiones aritméticas
#
# ### Expresión: `(3 + 5) * (2 - 1)`
#
# Árbol de expresión:
#
# ```
#        *
#       / \
#      +   -
#     / \ / \
#    3  5 2  1
# ```
#
# ### Aplicaciones:
# - Evaluación automática de expresiones
# - Análisis sintáctico en compiladores
# - Conversión entre notaciones (infix, postfix, prefix)
#
# Cada hoja es un operando (número), y cada nodo interno es un operador.

# %%
# Importamos la librería matplotlib para generar gráficos (plt es el alias común).
import matplotlib.pyplot as plt

# Importamos la librería networkx para trabajar con grafos dirigidos (nx es el alias común).
import networkx as nx

# Creamos un nuevo grafo dirigido (DiGraph significa "Directed Graph", es decir, con flechas).
G = nx.DiGraph()

# Definimos las conexiones (aristas) entre los nodos. Cada tupla representa una conexión de padre a hijo.
edges = [
    ('*', '+'),  # El nodo raíz '*' tiene como hijo izquierdo el operador '+'
    ('*', '-'),  # El nodo raíz '*' tiene como hijo derecho el operador '-'
    ('+', '3'),  # El nodo '+' tiene como hijo izquierdo el operando '3'
    ('+', '5'),  # El nodo '+' tiene como hijo derecho el operando '5'
    ('-', '2'),  # El nodo '-' tiene como hijo izquierdo el operando '2'
    ('-', '1')   # El nodo '-' tiene como hijo derecho el operando '1'
]

# Agregamos todas las aristas al grafo G. NetworkX creará automáticamente los nodos implicados.
G.add_edges_from(edges)

# Definimos las posiciones en el plano (x, y) para que el árbol se visualice ordenado y jerárquico.
pos = {
    '*': (0, 2),      # La raíz está en el nivel más alto
    '+': (-1, 1),     # Hijo izquierdo de '*'
    '-': (1, 1),      # Hijo derecho de '*'
    '3': (-1.5, 0),   # Hijo izquierdo de '+'
    '5': (-0.5, 0),   # Hijo derecho de '+'
    '2': (0.5, 0),    # Hijo izquierdo de '-'
    '1': (1.5, 0)     # Hijo derecho de '-'
}

# Creamos una nueva figura de tamaño 8x5 pulgadas
plt.figure(figsize=(8, 5))

# Dibujamos el grafo:
# - G: el grafo a dibujar
# - pos: las posiciones definidas para cada nodo
# - with_labels=True: muestra los nombres (etiquetas) de los nodos
# - node_color='lightblue': color de los nodos
# - node_size=2000: tamaño de los nodos
# - font_size=14, font_weight='bold': tamaño y grosor del texto
# - arrows=True: muestra flechas indicando dirección
nx.draw(
    G, pos,
    with_labels=True,
    node_color='lightblue',
    node_size=2000,
    font_size=14,
    font_weight='bold',
    arrows=True
)

# Título del gráfico
plt.title("Árbol de expresión: (3 + 5) * (2 - 1)")

# Muestra el gráfico en pantalla
plt.show()
